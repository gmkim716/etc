# %% [markdown]
# # 1. 데이터 다운로드

# %% [markdown]
# # 2. 간단한 데이터 확인 및 정리

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('iris_train.csv') # iris_train 데이터 불러오기
train.head()
# Out:
#    id     species  sepal length (cm)  petal length (cm)  sepal width (cm)  \
# 0   0      setosa                4.4                1.4               2.9
# 1   1  versicolor                6.4                4.5               3.2
# 2   2   virginica                6.2                4.8               2.8
# 3   3   virginica                7.2                6.1               3.6
# 4   4      setosa                4.9                1.4               3.0
#
#    petal width (cm)
# 0               0.2
# 1               1.5
# 2               1.8
# 3               2.5
# 4               0.2

# %%
train.describe() 
# describe를 통해 각각 feature의 수, 평균, 표준편차 등을 간단히 확인할 수 있다
# Out:
#               id  sepal length (cm)  petal length (cm)  sepal width (cm)  \
# count  75.000000          75.000000          75.000000         75.000000
# mean   37.000000           6.044000           4.258667          2.958667
# std    21.794495           0.842653           1.615390          0.388376
# min     0.000000           4.300000           1.100000          2.000000
# 25%    18.500000           5.550000           3.750000          2.800000
# 50%    37.000000           6.100000           4.700000          3.000000
# 75%    55.500000           6.600000           5.300000          3.200000
# max    74.000000           7.700000           6.900000          4.000000
#
#        petal width (cm)
# count         75.000000
# mean           1.384000
# std            0.697106
# min            0.100000
# 25%            1.000000
# 50%            1.500000
# 75%            1.850000
# max            2.500000

# %%
train['species'] = train['species'].map({'setosa':0,
                                        'versicolor':1,
                                        'virginica':2
                                        })
# EDA를 통해 붓꽃의 종류에 따라 길이, 너비의 차이가 있다는 사실을 알기 때문에
# 이를 학습에 사용하기 위해 각각 0, 1, 2 숫자로 바꾸어주었습니다.
train
# Out:
#     id  species  sepal length (cm)  petal length (cm)  sepal width (cm)  \
# 0    0        0                4.4                1.4               2.9
# 1    1        1                6.4                4.5               3.2
# 2    2        2                6.2                4.8               2.8
# 3    3        2                7.2                6.1               3.6
# 4    4        0                4.9                1.4               3.0
# ..  ..      ...                ...                ...               ...
# 70  70        1                6.5                4.6               2.8
# 71  71        1                5.6                3.6               2.9
# 72  72        1                6.2                4.5               2.2
# 73  73        1                4.9                3.3               2.4
# 74  74        1                6.9                4.9               3.1
#
#     petal width (cm)
# 0                0.2
# 1                1.5
# 2                1.8
# 3                2.5
# 4                0.2
# ..               ...
# 70               1.5
# 71               1.3
# 72               1.5
# 73               1.0
# 74               1.5
#
# [75 rows x 6 columns]

# %%
test = pd.read_csv('iris_test.csv') # 테스트 데이터 불러오기
test.head()
# Out:
#    id    species  sepal length (cm)  petal length (cm)
# 0   0     setosa                5.4                1.7
# 1   1     setosa                5.7                1.5
# 2   2     setosa                5.3                1.5
# 3   3     setosa                5.1                1.9
# 4   4  virginica                6.0                4.8

# %%
test.describe()
# Out:
#               id  sepal length (cm)  petal length (cm)
# count  75.000000          75.000000          75.000000
# mean   37.000000           5.642667           3.257333
# std    21.794495           0.767441           1.776816
# min     0.000000           4.400000           1.000000
# 25%    18.500000           5.100000           1.500000
# 50%    37.000000           5.500000           3.700000
# 75%    55.500000           6.150000           5.050000
# max    74.000000           7.900000           6.400000

# %%
test['species'] = test['species'].map({'setosa':0,
                                      'versicolor':1,
                                      'virginica':2
                                      })
# 학습 데이터와 마찬가지로 species를 숫자로 바꾸어주기
test
# Out:
#     id  species  sepal length (cm)  petal length (cm)
# 0    0        0                5.4                1.7
# 1    1        0                5.7                1.5
# 2    2        0                5.3                1.5
# 3    3        0                5.1                1.9
# 4    4        2                6.0                4.8
# ..  ..      ...                ...                ...
# 70  70        1                5.8                4.0
# 71  71        0                4.4                1.3
# 72  72        2                6.3                5.6
# 73  73        1                5.1                3.0
# 74  74        2                5.9                5.1
#
# [75 rows x 4 columns]

# %% [markdown]
# # 1. LazyRegressor를 통한 여러 Regression 결과 확인하기

# %%
# !pip install lazypredict

# %%
# import os # 중간에 pandas, numpy가 오류가 난다면 이 코드를 실행하고 처음부터 코드들 다시 실행하기
# os.kill(os.getpid(), 9)

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
from sklearn.model_selection import train_test_split

X = train[['species', 'sepal length (cm)', 'petal length (cm)']] # 학습 데이터에서 학습에 사용되는 feature만 가져오기
Y = train[['sepal width (cm)', 'petal width (cm)']] # 학습 데이터에서 예측에 사용되는 target값들 가져오기

X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=42) # train, test 데이터 나누기

# %%
def MAE(true, pred): # 우리가 사용할 평가지표 MAE 정의하기
    score = np.mean(np.abs(true-pred))
    return score

reg = LazyRegressor(verbose = 0, ignore_warnings = True, custom_metric=MAE) 
# LazyRegressor 모델을 생성하고, MAE를 custom_metric에 넣어주기
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 54.32it/s]
#                             Adjusted R-Squared  R-Squared  RMSE  Time Taken  \
# Model
# TransformedTargetRegressor                0.61       0.68  0.23        0.02
# Lars                                      0.61       0.68  0.23        0.02
# LinearRegression                          0.61       0.68  0.23        0.01
# RidgeCV                                   0.61       0.68  0.23        0.01
# Ridge                                     0.60       0.67  0.23        0.02
# KNeighborsRegressor                       0.56       0.63  0.24        0.01
# RANSACRegressor                           0.55       0.63  0.24        0.02
# OrthogonalMatchingPursuit                 0.39       0.49  0.29        0.02
# RandomForestRegressor                     0.36       0.47  0.29        0.11
# BaggingRegressor                          0.29       0.41  0.30        0.05
# ExtraTreesRegressor                       0.18       0.31  0.32        0.10
# ExtraTreeRegressor                        0.08       0.24  0.36        0.01
# ElasticNet                               -0.06       0.12  0.50        0.02
# LassoLars                                -0.23      -0.03  0.58        0.02
# DummyRegressor                           -0.23      -0.03  0.58        0.02
# Lasso                                    -0.23      -0.03  0.58        0.02
# DecisionTreeRegressor                    -0.30      -0.08  0.41        0.02
# MLPRegressor                             -1.54      -1.12  0.52        0.10
# KernelRidge                             -45.70     -37.92  2.34        0.02
# GaussianProcessRegressor               -501.08    -417.40  7.13        0.02
#
#                                                                           MAE
# Model
# TransformedTargetRegressor  sepal width (cm)   0.22
# petal width (cm)   0.1...
# Lars                        sepal width (cm)   0.22
# petal width (cm)   0.1...
# LinearRegression            sepal width (cm)   0.22
# petal width (cm)   0.1...
# RidgeCV                     sepal width (cm)   0.22
# petal width (cm)   0.1...
# Ridge                       sepal width (cm)   0.22
# petal width (cm)   0.1...
# KNeighborsRegressor         sepal width (cm)   0.23
# petal width (cm)   0.1...
# RANSACRegressor             sepal width (cm)   0.23
# petal width (cm)   0.1...
# OrthogonalMatchingPursuit   sepal width (cm)   0.25
# petal width (cm)   0.1...
# RandomForestRegressor       sepal width (cm)   0.27
# petal width (cm)   0.1...
# BaggingRegressor            sepal width (cm)   0.29
# petal width (cm)   0.1...
# ExtraTreesRegressor         sepal width (cm)   0.31
# petal width (cm)   0.1...
# ExtraTreeRegressor          sepal width (cm)   0.33
# petal width (cm)   0.2...
# ElasticNet                  sepal width (cm)   0.27
# petal width (cm)   0.5...
# LassoLars                   sepal width (cm)   0.27
# petal width (cm)   0.6...
# DummyRegressor              sepal width (cm)   0.27
# petal width (cm)   0.6...
# Lasso                       sepal width (cm)   0.27
# petal width (cm)   0.6...
# DecisionTreeRegressor       sepal width (cm)   0.39
# petal width (cm)   0.2...
# MLPRegressor                sepal width (cm)   0.58
# petal width (cm)   0.1...
# KernelRidge                 sepal width (cm)   2.97
# petal width (cm)   1.4...
# GaussianProcessRegressor    sepal width (cm)   4.23
# petal width (cm)   0.7...

# %%
# 가장 좋은 모델을 구글링해서 사용법 찾아보기
# 코드 작성자는 RANSCACRegressor의 RMSE와 MAE가 가장 낮아 선택하였다.
from sklearn.linear_model import RANSACRegressor

test = test[['species','sepal length (cm)','petal length (cm)']] # test 데이터에서 학습에 이용할 컬럼만 가져오기
reg = RANSACRegressor(random_state=0).fit(X,Y) # regressor 생성
reg.score(X, Y)

predict = reg.predict(test)

predict
# Out:
# array([[3.45350001, 0.2786458 ],
#        [3.72760059, 0.23780715],
#        [3.48679248, 0.22665065],
#        [3.17939943, 0.31948445],
#        [2.97092834, 1.89849883],
#        [2.71028254, 1.96672963],
#        [3.54699451, 0.22943977],
#        [3.35293365, 0.19368026],
#        [3.24598437, 0.21549415],
#        [2.80847964, 1.40447736],
#        [3.29273162, 0.19089114],
#        [3.23252959, 0.18810202],
#        [3.01129267, 1.98067525],
#        [3.36681087, 2.3451404 ],
#        [2.70791328, 1.31951182],
#        [3.05803992, 1.95607223],
#        [3.11212554, 0.18252377],
#        [3.37250484, 1.99740999],
#        [2.82193442, 1.43186949],
#        [2.65715237, 2.09811206],
#        [2.83775845, 2.10647944],
#        [2.99879335, 0.31111708],
#        [2.81486256, 1.29769793],
#        [3.31964118, 0.24567542],
#        [2.8814475 , 1.19370763],
#        [3.13903509, 0.23730804],
#        [3.27289393, 0.27027843],
#        [3.4733377 , 0.19925851],
#        [3.64048901, 0.18023375],
#        [3.23226309, 2.07121903],
#        [2.96855908, 1.25128103],
#        [3.42659045, 0.22386153],
#        [3.03846873, 0.15234251],
#        [2.93832482, 2.19144497],
#        [3.08494948, 2.01085651],
#        [3.36638843, 0.2210724 ],
#        [3.09867076, 0.15513163],
#        [2.76811531, 1.32230094],
#        [3.25943915, 0.24288629],
#        [3.13639934, 1.47320725],
#        [3.36638843, 0.2210724 ],
#        [3.3996809 , 0.16907725],
#        [3.20604248, 2.25738574],
#        [3.25943915, 0.24288629],
#        [3.38664857, 2.26575312],
#        [3.29911453, 0.08411172],
#        [2.8108489 , 2.05169516],
#        [2.76742636, 1.08134996],
#        [3.63410609, 0.28701317],
#        [3.02237819, 1.36084958],
#        [3.25943915, 0.24288629],
#        [2.55421675, 1.36592872],
#        [2.83470025, 1.21831064],
#        [2.44726748, 1.38774261],
#        [3.70069103, 0.18302287],
#        [2.52799615, 1.55209543],
#        [3.65394378, 0.20762588],
#        [2.75466053, 1.29490881],
#        [3.44642815, 0.14447424],
#        [3.03583297, 1.38824171],
#        [2.97161729, 2.13944982],
#        [2.74120575, 1.26751667],
#        [3.01836454, 2.11484681],
#        [2.8845057 , 2.08187642],
#        [3.07883307, 0.23451892],
#        [3.36638843, 0.2210724 ],
#        [3.20535353, 2.01643476],
#        [3.41313567, 0.19646939],
#        [3.42659045, 0.22386153],
#        [2.76811531, 1.32230094],
#        [2.92181183, 1.27588404],
#        [3.03846873, 0.15234251],
#        [2.77755643, 2.10369031],
#        [2.96787013, 1.01033004],
#        [2.77048456, 1.96951875]])

# %%
df = pd.DataFrame(predict)
df
# Out:
#       0    1
# 0  3.45 0.28
# 1  3.73 0.24
# 2  3.49 0.23
# 3  3.18 0.32
# 4  2.97 1.90
# ..  ...  ...
# 70 2.92 1.28
# 71 3.04 0.15
# 72 2.78 2.10
# 73 2.97 1.01
# 74 2.77 1.97
#
# [75 rows x 2 columns]

# %%
submission = pd.read_csv('sample_submission.csv')
submission.head()

submission['sepal width (cm)'] = np.array(df[0], np.float32)
submission['petal width (cm)'] = np.array(df[1], np.float32)

submission # 예측 데이터 확인
# Out:
#     id  sepal width (cm)  petal width (cm)
# 0    0              3.45              0.28
# 1    1              3.73              0.24
# 2    2              3.49              0.23
# 3    3              3.18              0.32
# 4    4              2.97              1.90
# ..  ..               ...               ...
# 70  70              2.92              1.28
# 71  71              3.04              0.15
# 72  72              2.78              2.10
# 73  73              2.97              1.01
# 74  74              2.77              1.97
#
# [75 rows x 3 columns]

# %%
submission.to_csv('submission_hello.csv', index=False) # 제출 파일 저장
